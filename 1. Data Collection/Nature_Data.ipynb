# %% [markdown]
# ## Web Scraping Approach
#
# A web scraping process aimed at collecting news articles from an online platform is performed. 3 libraries were used to carry out our web scraping process.
#
# - `requests`: Retrieving web page content.(Python Software Foundation, n.d.)
# - `BeautifulSoup`: Parsing and navigating the HTML structure of these pages for data extraction.(Mitchell & Richardson, n.d.)
# - `pandas`: To structure the scraped information into a format ready for further analysis. (McKinney, n.d.)
#
# Our extraction focuses on the articles titles and their main textual content, from a carefully chosen list of URLs. This required a process of identifying and extracting HTML elements known to house the title and body text, which were then compiled into a coherent dataset. This approach not only made the data collection process efficient for our needs but also helped the consistency and accuracy of the data prepared for analysis.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def scrape_nature_article(url):
    response = requests.get(url)
    if response.status_code != 200:
        return {'title': 'Failed to fetch article', 'text': ''}
    
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extracting the title
    title_tag = soup.find('h1', class_='c-article-magazine-title')
    article_title = title_tag.get_text(strip=True) if title_tag else 'No Title Found'
    
    # Extracting the teaser text
    teaser_text_tag = soup.find('div', class_='c-article-teaser-text')
    teaser_text = teaser_text_tag.get_text(strip=True) if teaser_text_tag else ''
    
    # Extracting the main article paragraphs
    article_body_texts = soup.find_all('p', class_='article__teaser')
    article_body = ' '.join([p.get_text(strip=True) for p in article_body_texts])
    
    # Combining teaser and main article body
    full_text = teaser_text + " " + article_body if teaser_text else article_body
    
    return {
        'title': article_title,
        'text': full_text.strip()
    }

# List of Nature URLs to scrape
urls = [
    'https://www.nature.com/articles/d41586-024-00576-w',
    'https://www.nature.com/articles/d41586-024-00662-z',
    'https://www.nature.com/articles/s41586-024-07176-8',
    'https://www.nature.com/articles/s41586-024-07186-6',
    'https://www.nature.com/articles/s41586-024-07187-5',
    'https://www.nature.com/articles/s41586-024-07096-7',
    'https://www.nature.com/articles/s41586-024-07167-9',
    'https://www.nature.com/articles/s41586-024-07159-9',
    'https://www.nature.com/articles/s41586-024-07058-z',
    'https://www.nature.com/articles/s41586-024-07150-4',
    'https://www.nature.com/articles/d41586-024-00780-8',
    'https://www.nature.com/articles/d41586-024-00895-y',
    'https://www.nature.com/articles/d41586-024-00886-z',
    'https://www.nature.com/articles/d41586-024-00828-9',
    'https://www.nature.com/articles/d41586-024-00839-6',
    'https://www.nature.com/articles/d41586-024-00795-1',
    'https://www.nature.com/articles/d41586-024-00747-9',
    'https://www.nature.com/articles/d41586-024-00720-6',
    'https://www.nature.com/articles/d41586-024-00661-0',
    'https://www.nature.com/articles/d41586-024-00695-4',
    'https://www.nature.com/articles/d41586-023-02240-1',
    'https://www.nature.com/articles/d41586-023-02357-3',
    'https://www.nature.com/articles/d41586-023-02333-x',
    'https://www.nature.com/articles/d41586-023-02215-2',
    'https://www.nature.com/articles/d41586-023-01618-5',
    'https://www.nature.com/articles/d41586-023-01935-9',
    'https://www.nature.com/articles/d41586-023-01890-5',
    'https://www.nature.com/articles/d41586-022-01932-4',
    'https://www.nature.com/articles/d41586-023-01491-2',
    'https://www.nature.com/articles/d41586-023-01355-9',
    'https://www.nature.com/articles/d41586-023-01020-1',
    'https://www.nature.com/articles/d41586-023-01023-y',
    'https://www.nature.com/articles/d41586-023-00979-1',
    'https://www.nature.com/articles/d41586-023-00850-3',
    'https://www.nature.com/articles/d41586-023-00835-2',
    'https://www.nature.com/articles/d41586-023-00847-y',
    'https://www.nature.com/articles/d41586-023-00798-4',
    'https://www.nature.com/articles/d41586-023-00710-0',
    'https://www.nature.com/articles/d41586-023-00755-1',
    'https://www.nature.com/articles/d41586-023-00597-x',
    'https://www.nature.com/articles/d41586-023-00531-1',
    'https://www.nature.com/articles/d41586-023-00539-7',
    'https://www.nature.com/articles/d41586-023-00475-6',
    'https://www.nature.com/articles/d41586-023-00268-x',
    'https://www.nature.com/articles/d41586-023-00243-6',
    'https://www.nature.com/articles/d41586-023-00225-8',
    'https://www.nature.com/articles/d41586-023-00195-x',
    'https://www.nature.com/articles/d41586-023-00027-y',
    'https://www.nature.com/articles/d41586-023-00068-3',
    'https://www.nature.com/articles/d41586-022-04494-7'
]

# Scraping the articles and collect the data
articles = []
for url in urls:
    result = scrape_nature_article(url)
    if result:
        articles.append({
            'url': url,
            'title': result['title'],
            'text': result['text'],
            'label': 'Human-written'
        })

nature_df = pd.DataFrame(articles)

# %%
nature_df
# Out:
#                                                   url  \
# 0   https://www.nature.com/articles/d41586-024-005...
# 1   https://www.nature.com/articles/d41586-024-006...
# 2   https://www.nature.com/articles/s41586-024-071...
# 3   https://www.nature.com/articles/s41586-024-071...
# 4   https://www.nature.com/articles/s41586-024-071...
# 5   https://www.nature.com/articles/s41586-024-070...
# 6   https://www.nature.com/articles/s41586-024-071...
# 7   https://www.nature.com/articles/s41586-024-071...
# 8   https://www.nature.com/articles/s41586-024-070...
# 9   https://www.nature.com/articles/s41586-024-071...
# 10  https://www.nature.com/articles/d41586-024-007...
# 11  https://www.nature.com/articles/d41586-024-008...
# 12  https://www.nature.com/articles/d41586-024-008...
# 13  https://www.nature.com/articles/d41586-024-008...
# 14  https://www.nature.com/articles/d41586-024-008...
# 15  https://www.nature.com/articles/d41586-024-007...
# 16  https://www.nature.com/articles/d41586-024-007...
# 17  https://www.nature.com/articles/d41586-024-007...
# 18  https://www.nature.com/articles/d41586-024-006...
# 19  https://www.nature.com/articles/d41586-024-006...
# 20  https://www.nature.com/articles/d41586-023-022...
# 21  https://www.nature.com/articles/d41586-023-023...
# 22  https://www.nature.com/articles/d41586-023-023...
# 23  https://www.nature.com/articles/d41586-023-022...
# 24  https://www.nature.com/articles/d41586-023-016...
# 25  https://www.nature.com/articles/d41586-023-019...
# 26  https://www.nature.com/articles/d41586-023-018...
# 27  https://www.nature.com/articles/d41586-022-019...
# 28  https://www.nature.com/articles/d41586-023-014...
# 29  https://www.nature.com/articles/d41586-023-013...
# 30  https://www.nature.com/articles/d41586-023-010...
# 31  https://www.nature.com/articles/d41586-023-010...
# 32  https://www.nature.com/articles/d41586-023-009...
# 33  https://www.nature.com/articles/d41586-023-008...
# 34  https://www.nature.com/articles/d41586-023-008...
# 35  https://www.nature.com/articles/d41586-023-008...
# 36  https://www.nature.com/articles/d41586-023-007...
# 37  https://www.nature.com/articles/d41586-023-007...
# 38  https://www.nature.com/articles/d41586-023-007...
# 39  https://www.nature.com/articles/d41586-023-005...
# 40  https://www.nature.com/articles/d41586-023-005...
# 41  https://www.nature.com/articles/d41586-023-005...
# 42  https://www.nature.com/articles/d41586-023-004...
# 43  https://www.nature.com/articles/d41586-023-002...
# 44  https://www.nature.com/articles/d41586-023-002...
# 45  https://www.nature.com/articles/d41586-023-002...
# 46  https://www.nature.com/articles/d41586-023-001...
# 47  https://www.nature.com/articles/d41586-023-000...
# 48  https://www.nature.com/articles/d41586-023-000...
# 49  https://www.nature.com/articles/d41586-022-044...
#
#                                                 title  \
# 0     Magnetic whirlpools offer improved data storage
# 1   Whittling down the bacterial subspecies that m...
# 2                                      No Title Found
# 3                                      No Title Found
# 4                                      No Title Found
# 5                                      No Title Found
# 6                                      No Title Found
# 7                                      No Title Found
# 8                                      No Title Found
# 9                                      No Title Found
# 10              How AI is improving climate forecasts
# 11  How a tree-hugging protest transformed Indian ...
# 12  How to achieve safe water access for all: work...
# 13        COVID’s toll on the brain: new clues emerge
# 14  Mathematician who tamed randomness wins Abel P...
# 15  How to stop ‘passing the harasser’: universiti...
# 16  First US drug approved for a liver disease sur...
# 17  Why are so many young people getting cancer? W...
# 18  How OpenAI’s text-to-video tool Sora could cha...
# 19      China promises more money for science in 2024
# 20  How the cGAS–STING system links inflammation a...
# 21  From the archive: the problem with physics, an...
# 22  Heat-assisted imaging enables day-like visibil...
# 23  Dynamics of protein droplets revealed by bridg...
# 24  Sleeping embryonic genomes are awoken by OBOX ...
# 25  Rarely used strained molecules step up for org...
# 26           A mitotic glue for shattered chromosomes
# 27   A step closer to making the mother of stem cells
# 28  From the archive: sunshine statistics, and the...
# 29              An unexpected timer for cell division
# 30  DART’s data verify its smashing success at def...
# 31  COVID pandemic increased racial disparities in...
# 32  Earth’s molten youth had long-lasting conseque...
# 33         The medieval Moon unveils volcanic secrets
# 34   Southern Ocean heat sink hindered by melting ice
# 35  Mix-and-match tools for protein injection into...
# 36       Hazards help autonomous cars to drive safely
# 37     Swift progress for robots over complex terrain
# 38  Eggs made from male mouse stem cells using err...
# 39  From the archive: ancient mazes, and ants unde...
# 40  Carbon stocks of billions of individual Africa...
# 41  Path unveiled for protein entry into chloroplasts
# 42  From the archive: machine intelligence, and th...
# 43      The extent and drivers of global wetland loss
# 44  Fish fossil unfolds clues to vertebrate brain ...
# 45  Light tailors the electronic properties of a m...
# 46       Bacterial defence repurposed to fight blight
# 47  Broken mirror symmetry boosts current conversi...
# 48  Time of day shapes the success of a cancer tre...
# 49        A neural strategy for directional behaviour
#
#                                                  text          label
# 0   Complex magnetic structures called skyrmions h...  Human-written
# 1   Understanding the factors that drive formation...  Human-written
# 2                                                      Human-written
# 3                                                      Human-written
# 4                                                      Human-written
# 5                                                      Human-written
# 6                                                      Human-written
# 7                                                      Human-written
# 8                                                      Human-written
# 9                                                      Human-written
# 10  Researchers are using various machine-learning...  Human-written
# 11  Fifty years ago, a group of women from the vil...  Human-written
# 12  Four scientists reflect on how to foster a mor...  Human-written
# 13  A leaky blood–brain barrier and inflammation m...  Human-written
# 14  Michel Talagrand laid mathematical groundwork ...  Human-written
# 15  The Misconduct Disclosure Scheme would make it...  Human-written
# 16  A therapy called resmetirom improves hallmarks...  Human-written
# 17  Clues to a modern mystery could be lurking in ...  Human-written
# 18  OpenAI’s debut of its impressive Sora text-to-...  Human-written
# 19  Science and innovation are central to China’s ...  Human-written
# 20  When DNA is misplaced inside cells, the cGAS–S...  Human-written
# 21          Snippets fromNature’s past. 100 years ago  Human-written
# 22  An imaging technique that uses a neural-networ...  Human-written
# 23  Many biological processes rely on proteins tha...  Human-written
# 24  Activation of gene transcription is precisely ...  Human-written
# 25  Energy released from molecules under strain ca...  Human-written
# 26  Two studies now shed light on how chromosomes ...  Human-written
# 27  In the earliest stages of mammalian developmen...  Human-written
# 28          Snippets fromNature’s past. 100 years ago  Human-written
# 29  A serendipitous observation has revealed that ...  Human-written
# 30  A strategy for deflecting asteroids on a path ...  Human-written
# 31  A public data set on the size and racial compo...  Human-written
# 32  A model shows that key physical properties of ...  Human-written
# 33  Innovative use of medieval musings about the M...  Human-written
# 34  Simulations show that the melting of Antarctic...  Human-written
# 35  An injection system from bacteria has been re-...  Human-written
# 36  Collecting training data by focusing on danger...  Human-written
# 37  A four-legged robot has learnt to run on sand ...  Human-written
# 38  A screen of mouse stem cells that exploits the...  Human-written
# 39          Snippets fromNature’s past. 100 years ago  Human-written
# 40  An inventory of nearly 10 billion individual t...  Human-written
# 41  Structures of the machinery for importing prot...  Human-written
# 42           Snippets fromNature’s past. 50 years ago  Human-written
# 43  An impressive combination of modelling and dat...  Human-written
# 44  A 319-million-year-old fossil provides the old...  Human-written
# 45  When a semiconductor material called black pho...  Human-written
# 46  The discovery of bacterial compounds that have...  Human-written
# 47  The intrinsic structure of a material called a...  Human-written
# 48  Daily rhythms affect many aspects of mammalian...  Human-written
# 49  How does a fruit fly’s brain determine which w...  Human-written

# %%
(nature_df['text'] == '').sum()
# Out:
# 8

# %%
nature_df = nature_df[nature_df['text'] != '']

# %%
(nature_df['text'] == '').sum()
# Out:
# 0

# %%
nature_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 42 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   url     42 non-null     object
#  1   title   42 non-null     object
#  2   text    42 non-null     object
#  3   label   42 non-null     object
# dtypes: object(4)
# memory usage: 1.6+ KB

# %% [markdown]
# ## Data storage for further analysis
#
# After successfully scraping and organizing the data, it is stored. This step allowed us to keep a stable and easily accessible dataset for further analysis, obviating the need to redo the scraping process. Opting for a pickle file as the storage medium was particularly advantageous due to its capacity to store Python objects, thereby maintaining the integrity of the data's structure and content.

# %%
nature_df.to_pickle("nature_data.pkl")

# %% [markdown]
# ### References
#
# - Python Software Foundation. (n.d.). *Requests: HTTP for Humans™*. Retrieved from [https://requests.readthedocs.io](https://requests.readthedocs.io)
#
# - Richard Mitchell, Leonard Richardson. (n.d.). *Beautiful Soup Documentation*. Retrieved from [https://www.crummy.com/software/BeautifulSoup/bs4/doc/](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
#
# - Wes McKinney. (n.d.). *pandas: powerful Python data analysis toolkit*. Retrieved from [https://pandas.pydata.org/pandas-docs/stable/index.html](https://pandas.pydata.org/pandas-docs/stable/index.html)
