# %% [markdown]
# ## Web Scraping Approach
#
# A web scraping process aimed at collecting news articles from Al Jazeera's online platform is performed. 3 libraries were used to carry out our web scraping process.
#
# - `requests`: Retrieving web page content.(Python Software Foundation, n.d.)
# - `BeautifulSoup`: Parsing and navigating the HTML structure of these pages for data extraction.(Mitchell & Richardson, n.d.)
# - `pandas`: To structure the scraped information into a format ready for further analysis. (McKinney, n.d.)
#
# Our extraction focuses on the articles titles and their main textual content, from a carefully chosen list of URLs. This required a process of identifying and extracting HTML elements known to house the title and body text, which were then compiled into a coherent dataset. This approach not only made the data collection process efficient for our needs but also helped the consistency and accuracy of the data prepared for analysis.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def scrape_techcrunch_article(url):
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for non-200 status codes

        soup = BeautifulSoup(response.content, 'html.parser')

        title_element = soup.find('h1', class_='article__title')  
        title = title_element.text.strip() if title_element else 'TechCrunch Article'

        content_element = soup.find('div', class_='article-content') 
        if content_element:
            paragraphs = content_element.find_all('p')
            text = ' '.join(p.get_text(strip=True) for p in paragraphs)
        else:
            text = 'Content not found'

        return {
            'url': url,
            'title': title,
            'text': text,
            'label': 'Human-written'
        }
    except requests.exceptions.RequestException as e:
        print(f"Error fetching URL: {e}")
        return None

# List of TechCrunch URLs to scrape
techcrunch_urls = [
    'https://techcrunch.com/2024/03/27/linkedin-is-experimenting-with-a-tiktok-like-video-feed-in-its-app/',
    'https://techcrunch.com/2024/03/27/marissa-mayers-startup-just-rolled-out-apps-for-group-photo-sharing-and-event-planning-and-the-internet-isnt-sure-what-to-think/',
    'https://techcrunch.com/2024/03/27/databricks-spent-10m-on-a-generative-ai-model-that-still-cant-beat-gpt-4/',
    'https://techcrunch.com/2024/03/27/uk-unicorn-new-york-hologram-venture-capital/',
    'https://techcrunch.com/2024/03/27/unicorn-founders/',
    'https://techcrunch.com/2024/03/27/wase-seed-fundraise/',
    'https://techcrunch.com/2024/03/13/tech-layoffs-2023-list/',
    'https://techcrunch.com/2024/03/26/apple-wwdc-2024-set-for-june-10-14-promises-to-be-absolutely-incredible/',
    'https://techcrunch.com/2024/03/26/robinhood-goes-after-apple-card-with-a-new-credit-card-loaded-with-impressive-features/',
    'https://techcrunch.com/2024/03/26/apple-wwdc-2024-set-for-june-10-14-promises-to-be-absolutely-incredible/',
    'https://techcrunch.com/2024/03/26/with-affinity-acquisition-canva-should-be-able-to-compete-better-with-adobes-creative-tools/',
    'https://techcrunch.com/2024/03/13/chatgpt-everything-to-know-about-the-ai-chatbot/',
    'https://techcrunch.com/2024/03/27/newretirement-wants-to-simplify-financial-planning-for-retirement/',
    'https://techcrunch.com/2024/03/27/google-generate-travel-itineraries-for-your-vacations/',
    'https://techcrunch.com/2024/03/27/google-swipe-clothes-better-fashion-recommendations/',
    'https://techcrunch.com/2024/03/27/techcrunch-minute-robinhoods-credit-card-has-arrived-to-take-on-apple-and-any-upcoming-challengers/',
    'https://techcrunch.com/2024/03/27/musical-toy-startup-playtime-engineering-wants-to-simplify-electronic-music-making-for-kids/',
    'https://techcrunch.com/2024/03/27/cyvl-ai-is-bringing-data-driven-solutions-to-transportation-infrastructure/',
    'https://techcrunch.com/2024/03/27/orchard-robotics-ai-powered-camera-system-turns-existing-farm-equipment-into-apple-growing-data-collectors/',
    'https://techcrunch.com/2024/03/27/observe-snowflake-data-observability/',
# 51  https://techcrunch.com/2024/03/26/viam-looks-b...
# 52  https://techcrunch.com/2024/03/26/picogrid-sco...
#
#                                                 title  \
# 0   LinkedIn is experimenting with a TikTok-like v...
# 1   Marissa Mayer’s startup just rolled out photo ...
# 2   Databricks spent $10M on new DBRX generative A...
# 3   The UK threw a splashy event in New York this ...
# 4   New study of unicorn founders finds most are ‘...
# 5   Wase zaps microbes to squeeze more biogas from...
# 6    A comprehensive list of 2023 & 2024 tech layoffs
# 7   Apple WWDC 2024, set for June 10-14, promises ...
# 8   Robinhood’s new credit card goes after Apple C...
# 9   Apple WWDC 2024, set for June 10-14, promises ...
# 10  With Affinity acquisition, Canva should be abl...
# 11  ChatGPT: Everything you need to know about the...
# 12  NewRetirement aims to shake up retirement plan...
# 13  Google will now let you use AI to build travel...
# 14  Google will let you swipe right or left on clo...
# 15  TechCrunch Minute: Robinhood’s credit card has...
# 16  Musical toy startup Playtime Engineering wants...
# 17  Cyvl.ai is bringing data-driven solutions to t...
# 18  Orchard vision system turns farm equipment int...
# 19  Observe, the data observability platform, rais...
# 20  Century Health, now with $2M, taps AI to give ...
# 21  Act fast — just 3 days remain to grab your Tec...
# 22  New Summit is raising a new $100 million fund ...
# 23  Amazon will have to publish an ads library in ...
# 24  Robinhood’s new credit card goes after Apple C...
# 25  Databricks spent $10M on new DBRX generative A...
# 26   A comprehensive list of 2023 & 2024 tech layoffs
# 27  Amazon fined in Poland for dark pattern design...
# 28  African B2B e-commerce giant Wasoko marked dow...
# 29  Rabbit partners with ElevenLabs to power voice...
# 30  Marissa Mayer’s startup just rolled out photo ...
# 31  PayPal backs Indonesian insurance startup Qoal...
# 32  Elon Musk says all Premium subscribers on X wi...
# 33  Discipulus Ventures mentors young founders to ...
# 34  How to turn off Instagram’s political content ...
# 35  Facebook snooped on users’ Snapchat traffic in...
# 36  NASA’s snake robot is designed to search out l...
# 37  Vibrant Planet uses AI for land mapping and im...
# 38  Synctera is the latest banking-as-a-service st...
# 39  EU publishes election security guidance for so...
# 40  Evari turns to rocket science to solve problem...
# 41  Adobe’s GenStudio brings brand-safe generative...
# 42  Confetti, a team-building platform used by App...
# 43  Tesla is pushing a free one-month trial of its...
# 44  Former Nextdoor exec raises $25 million for Pi...
# 45  Ionobell is turning to recycled silicon to boo...
# 46  Fireworks.ai open source API puts generative A...
# 47  Evoloh bets hydrogen won’t happen without bett...
# 48  Food-as-medicine startup Chiyo helps postpartu...
# 49  Just 4 days left to cash in on early-bird savi...
# 50  0G Labs launches with whopping $35M pre-seed t...
# 51  Viam looks beyond robotics with its automation...
# 52  Picogrid scores new funding to connect the mil...
#
#                                                  text          label
# 0   LinkedIn is testing a new TikTok-like short-fo...  Human-written
# 1   When Marissa Mayer co-founded a startup six ye...  Human-written
# 2   If you wanted to raise the profile of your maj...  Human-written
# 3   A 3D hologram, dubbed the Ever-Changing Statue...  Human-written
# 4   A new study that zeros-in on the founders of s...  Human-written
# 5   Few people get as excited about wastewater as ...  Human-written
# 6   The tech-widereckoningthat began in 2022and ra...  Human-written
# 7   Apple SVP Greg “Joz” Joswiak just confirmed vi...  Human-written
# 8   Eight months afteracquiring credit card startu...  Human-written
# 9   Apple SVP Greg “Joz” Joswiak just confirmed vi...  Human-written
# 10  Canva, the high-flying Australian design and v...  Human-written
# 11  ChatGPT, OpenAI’s text-generating AI chatbot, ...  Human-written
# 12  When entrepreneur Stephen Chen’s mom began app...  Human-written
# 13  As we inch toward the summer holidays, Google ...  Human-written
# 14  Google is rolling out an update that makes it ...  Human-written
# 15  Robinhood’s new credit card was revealed Tuesd...  Human-written
# 16  Troy Sheets began making music at 15 years old...  Human-written
# 17  In the summer after his freshman year at Worce...  Human-written
# 18  Agricultural robotics are not a new phenomenon...  Human-written
# 19  Enterprises today store and use data across an...  Human-written
# 20  Artificial intelligence can find hidden signal...  Human-written
# 21  March 29 is the final day to grab your early-b...  Human-written
# 22  New Summit Investmentsis raising a new $100 mi...  Human-written
# 23  Amazonwill have to provide information about t...  Human-written
# 24  Eight months afteracquiring credit card startu...  Human-written
# 25  If you wanted to raise the profile of your maj...  Human-written
# 26  The tech-widereckoningthat began in 2022and ra...  Human-written
# 27  Amazonhas been fined in Poland for misleading ...  Human-written
# 28  VNV Global, a Swedish investment firm that bac...  Human-written
# 29  Hardware makerRabbithas tapped a partnership w...  Human-written
# 30  When Marissa Mayer co-founded a startup six ye...  Human-written
# 31  PayPal Ventures’ latest investment is in an In...  Human-written
# 32  Following Elon Musk’s xAI’s move toopen source...  Human-written
# 33  Scores of accelerator programs run every year ...  Human-written
# 34  It’s election season in the U.S., and Instagra...  Human-written
# 35  In 2016, Facebook launched a secret project de...  Human-written
# 36  The snake robot form factor has existed for de...  Human-written
# 37  As the planet warms due to human-caused climat...  Human-written
# 38  Banking-as-a-service startup (BaaS)Syncterahas...  Human-written
# 39  The European Union published draft election se...  Human-written
# 40  Off a highway nestled in the woods of New Hamp...  Human-written
# 41  Brands want to use generative AI to personaliz...  Human-written
# 42  Not many startupscan claim Apple, Google, Micr...  Human-written
# 43  Tesla isabout to startgiving every customer in...  Human-written
# 44  Dan Laufer swore off ever founding a startup a...  Human-written
# 45  In the quest to coax more capacity from electr...  Human-written
# 46  Just about everyone is trying to get a piece o...  Human-written
# 47  The path to starting a business is sometimes o...  Human-written
# 48  One of the hardest things about being pregnant...  Human-written
# 49  Time is slipping away! With only 4 days left, ...  Human-written
# 50  As the crypto space heats back up, so has fund...  Human-written
# 51  Since the last time we spoke, Viam didn’t pivo...  Human-written
# 52  Autonomous systems have become essential to mi...  Human-written

# %% [markdown]
# ## Data storage for further analysis
#
# After successfully scraping and organizing the data, it is stored in a pickle file named `aljazeera_articles.pkl`. This step allowed us to keep a stable and easily accessible dataset for further analysis, obviating the need to redo the scraping process. Opting for a pickle file as the storage medium was particularly advantageous due to its capacity to store Python objects, thereby maintaining the integrity of the data's structure and content.

# %%
df.to_pickle("techcrunch_data.pkl")
print("Data scraped and saved to techcrunch_data.pkl")
# Out:
# Data scraped and saved to techcrunch_data.pkl

# %% [markdown]
# ### References
#
# - Python Software Foundation. (n.d.). *Requests: HTTP for Humans™*. Retrieved from [https://requests.readthedocs.io](https://requests.readthedocs.io)
#
# - Richard Mitchell, Leonard Richardson. (n.d.). *Beautiful Soup Documentation*. Retrieved from [https://www.crummy.com/software/BeautifulSoup/bs4/doc/](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
#
# - Wes McKinney. (n.d.). *pandas: powerful Python data analysis toolkit*. Retrieved from [https://pandas.pydata.org/pandas-docs/stable/index.html](https://pandas.pydata.org/pandas-docs/stable/index.html)
